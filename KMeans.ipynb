# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples=500, n_features=2, centers=4, random_state=1)

# %%
fig, ax1= plt.subplots(1)
ax1.scatter(X[:,0], X[:,1],marker='o',s=8)
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
cluster = KMeans(n_clusters= 3, random_state=0).fit(X)

y_pred = cluster.labels_
y_pred

pre = cluster.fit_predict(X)
pre == y_pred

sil_score= silhouette_score(X, y_pred)
print(sil_score)

centroid = cluster.cluster_centers_
print(centroid.shape)

inertia = cluster.inertia_
print(inertia)

color = ['red', 'pink', 'orange', 'gray', 'green', 'blue', 'yellow', 'purple']
fig, ax1= plt.subplots(1)
for i in range(centroid.shape[0]):
    ax1.scatter(X[y_pred==i,0], X[y_pred==i,1],marker='o',s=8,c=color[i])
    ax1.scatter(centroid[:,0], centroid[:,1],marker='x',s=15,c='black')
plt.show()
# Out:
# 0.5882004012129721
# (3, 2)
# 1903.4503741659241

# %%
cluster = KMeans(n_clusters= 4, random_state=0).fit(X)

y_pred = cluster.labels_
y_pred

pre = cluster.fit_predict(X)
pre == y_pred


sil_score= silhouette_score(X, y_pred)
print(sil_score)

centroid = cluster.cluster_centers_
print(centroid.shape)

inertia = cluster.inertia_
print(inertia)

color = ['red', 'pink', 'orange', 'gray', 'green', 'blue', 'yellow', 'purple']
fig, ax1= plt.subplots(1)
for i in range(centroid.shape[0]):
    ax1.scatter(X[y_pred==i,0], X[y_pred==i,1],marker='o',s=8,c=color[i])
    ax1.scatter(centroid[:,0], centroid[:,1],marker='x',s=15,c='black')
plt.show()
# Out:
# 0.6505186632729437
# (4, 2)
# 908.3855684760603

# %%
cluster = KMeans(random_state=0).fit(X)

y_pred = cluster.labels_
y_pred

pre = cluster.fit_predict(X)
pre == y_pred


sil_score= silhouette_score(X, y_pred)
print(sil_score)

centroid = cluster.cluster_centers_
print(centroid.shape)

inertia = cluster.inertia_
print(inertia)

color = ['red', 'pink', 'orange', 'gray', 'green', 'blue', 'yellow', 'purple']
fig, ax1= plt.subplots(1)
for i in range(centroid.shape[0]):
    ax1.scatter(X[y_pred==i,0], X[y_pred==i,1],marker='o',s=8,c=color[i])
    ax1.scatter(centroid[:,0], centroid[:,1],marker='x',s=15,c='black')
plt.show()
# Out:
# 0.32590063917105727
# (8, 2)
# 580.0143612963261

# %%
cluster = KMeans(n_clusters= 6, random_state=0).fit(X)

y_pred = cluster.labels_
y_pred

pre = cluster.fit_predict(X)
pre == y_pred

sil_score= silhouette_score(X, y_pred)
print(sil_score)

centroid = cluster.cluster_centers_
print(centroid.shape)

inertia = cluster.inertia_
print(inertia)

color = ['red', 'pink', 'orange', 'gray', 'green', 'blue', 'yellow', 'purple']
fig, ax1= plt.subplots(1)
for i in range(centroid.shape[0]):
    ax1.scatter(X[y_pred==i,0], X[y_pred==i,1],marker='o',s=8,c=color[i])
    ax1.scatter(centroid[:,0], centroid[:,1],marker='x',s=15,c='black')
plt.show()
# Out:
# 0.5150064498560357
# (6, 2)
# 733.1538350083074

# %%
cluster = KMeans(n_clusters= 2, random_state=0).fit(X)

y_pred = cluster.labels_
y_pred

pre = cluster.fit_predict(X)
pre == y_pred

sil_score= silhouette_score(X, y_pred)
print(sil_score)

centroid = cluster.cluster_centers_
print(centroid.shape)

inertia = cluster.inertia_
print(inertia)

color = ['red', 'pink', 'orange', 'gray', 'green', 'blue', 'yellow', 'purple']
fig, ax1= plt.subplots(1)
for i in range(centroid.shape[0]):
    ax1.scatter(X[y_pred==i,0], X[y_pred==i,1],marker='o',s=8,c=color[i])
    ax1.scatter(centroid[:,0], centroid[:,1],marker='x',s=15,c='black')
plt.show()
# Out:
# 0.7049787496083262
# (2, 2)
# 3735.405674929567
